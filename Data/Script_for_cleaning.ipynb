# %%
import os
import regex as re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### CPI

# %%
cpi = pd.read_excel('/content/drive/MyDrive/Leipzig/Divergenz_Projekt/Monthly_Index.xlsx')

# %%
cpi
# Out:
#     GEOGRAPHICAL AREA  Austria (AT)  Belgium (BE)  Cyprus (CY)  Estonia (EE)  \
# 0          1999-01-31         73.27         72.44          NaN           NaN
# 1          1999-02-28         73.42         72.59          NaN           NaN
# 2          1999-03-31         73.49         72.66          NaN           NaN
# 3          1999-04-30         73.49         72.94          NaN           NaN
# 4          1999-05-31         73.56         73.08          NaN           NaN
# ..                ...           ...           ...          ...           ...
# 297        2023-10-31        132.24        127.15       117.32        150.45
# 298        2023-11-30        132.46        127.05       115.51        150.48
# 299        2023-12-31        133.08        128.45       114.09        150.45
# 300        2024-01-31        132.60        127.51       112.67        152.35
# 301        2024-02-29        133.47        130.54       113.60        152.54
#
# ...

# %%
cpi.index = pd.to_datetime(cpi['GEOGRAPHICAL AREA'], format='%Y-%m-%d')
cpi = cpi.drop('GEOGRAPHICAL AREA', axis=1)

# %%
cpi_q = cpi.resample('QS').mean()

# %%
cpi_q
# Out:
#                    Austria (AT)  Belgium (BE)  Cyprus (CY)  Estonia (EE)  \
# GEOGRAPHICAL AREA
# 1999-01-01            73.393333     72.563333          NaN           NaN
# 1999-04-01            73.440000     72.986667          NaN           NaN
# 1999-07-01            73.420000     73.056667          NaN           NaN
# 1999-10-01            74.063333     73.406667          NaN           NaN
# 2000-01-01            74.683333     73.763333          NaN           NaN
# ...                         ...           ...          ...           ...
# 2023-01-01           128.046667    125.960000      111.400    146.166667
# 2023-04-01           130.120000    124.783333      114.050    150.473333
# 2023-07-01           130.836667    125.993333      116.910    150.993333
# 2023-10-01           132.593333    127.550000      115.640    150.460000
# 2024-01-01           133.035000    129.025000      113.135    152.445000
#
# ...

# %%
cpi_q.to_excel('/content/drive/MyDrive/Leipzig/Divergenz_Projekt/Monthly_Index_Q.xlsx')

# %% [markdown]
# ### Wages

# %%
wages = pd.read_excel('/content/drive/MyDrive/Leipzig/Divergenz_Projekt/Wages_Q.xlsx')

# %%
wages.index = pd.to_datetime(wages['GEOGRAPHICAL AREA'], format='%Y-%m-%d')
wages = wages.drop('GEOGRAPHICAL AREA', axis=1)

# %%
wages_percentage = wages.pct_change(4) * 100

# %%
wages_percentage.to_excel('/content/drive/MyDrive/Leipzig/Divergenz_Projekt/Wages_Percentage_Q.xlsx')

# %% [markdown]
# ### Balance of Trade

# %%
bot = pd.read_excel('/content/drive/MyDrive/Leipzig/Divergenz_Projekt/transformed_net_exports_per_month.xlsx')

# %%
bot.index = pd.to_datetime(bot['Date'], format='%Y-%m-%d')
bot = bot.drop('Date', axis=1)

# %%
bot = bot.resample('QS').mean()

# %%
bot.to_excel('/content/drive/MyDrive/Leipzig/Divergenz_Projekt/Balance_of_Trade_Q.xlsx')

# %% [markdown]
# ### Shadow Rate

# %%
srate = pd.read_excel('/content/drive/MyDrive/Leipzig/Divergenz_Projekt/shadowrate_ECB.xls', names=['Date', 'Rate'] )

# %%
srate['Date'] = pd.to_datetime(srate['Date'], format='%Y%m')
srate.set_index('Date', inplace=True)

# %%
srate_quarterly = srate.resample('Q').mean()

# %%
srate_quarterly.to_excel('/content/drive/MyDrive/Leipzig/Divergenz_Projekt/Srate_Q.xlsx')
